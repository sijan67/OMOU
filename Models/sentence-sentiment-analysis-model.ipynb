# %% [markdown]
# # Sentence Emotion Detection Model
#
# This notebook contains code we used to train our model that uses sentiment analysis to predict the emotion of the use based on a journal like sentence used as input

# %% [markdown]
# ## Dataset
#
# Our datasets

# %% [markdown]
# Install SpaCy and other libraries

# %%
# !pip install --upgrade torch==1.7.1 torchtext==0.8.1 torchvision==0.8.2
# Out:
# ...
#      |████████████████████████████████| 776.8MB 21kB/s
# ...
#      |████████████████████████████████| 7.0MB 45.5MB/s
# ...
#      |████████████████████████████████| 12.8MB 7.1MB/s
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
#   Found existing installation: torchtext 0.9.1
#     Uninstalling torchtext-0.9.1:
#       Successfully uninstalled torchtext-0.9.1
#   Found existing installation: torchvision 0.9.1+cu101
#     Uninstalling torchvision-0.9.1+cu101:
#       Successfully uninstalled torchvision-0.9.1+cu101
# ...

# %%
import torch, torchtext
from torch import nn, optim, functional as F
import pandas as pd, csv
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import pdb

# %%
tweets = pd.read_csv('https://www.dropbox.com/s/i0nb9una5iba8u8/tweet_emotions_orig.csv?dl=0https://www.dropbox.com/s/i0nb9una5iba8u8/tweet_emotions_orig.csv?dl=0')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-96469f2feefc> in <module>()
# ----> 1 tweets = pd.read_csv('https://www.dropbox.com/s/i0nb9una5iba8u8/tweet_emotions_orig.csv?dl=0https://www.dropbox.com/s/i0nb9una5iba8u8/tweet_emotions_orig.csv?dl=0')
#
# ...
