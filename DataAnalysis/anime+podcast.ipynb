# %%
import tensorflow as tf
import keras
from tensorflow.python.keras.preprocessing.text import Tokenizer

# %%
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
import re
from tensorflow.python.keras import backend
from tensorflow.python.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pip install np_utils
# Out:
# Requirement already satisfied: np_utils in /usr/local/lib/python3.7/dist-packages (0.5.12.1)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.7/dist-packages (from np_utils) (1.19.5)
# Requirement already satisfied: future>=0.16 in /usr/local/lib/python3.7/dist-packages (from np_utils) (0.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
podcast_model = keras.models.load_model('/content/drive/MyDrive/podcast_model.h5')

# %%
df = pd.read_csv('/content/drive/MyDrive/poddf.csv')

# %%
tokenizer = Tokenizer(num_words=5000, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
MAX_SEQUENCE_LENGTH = 250

# %%
new_summary  = [' NOOOOOOOOO ']
seq = tokenizer.texts_to_sequences(new_summary )
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = podcast_model.predict(padded)
labels = ['Literature', 'Business News', 'Comedy' ,'History', 'Places & Travel']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.2989716  0.22055312 0.14677978 0.21166296 0.12203252]] Literature

# %%
pred_val = labels[np.argmax(pred)]
print(pred_val)
# Out:
# Literature

# %%
recommend =df[df["Genre"] == pred_val].head(20)

# %%
recommend["Name"] #recommended podcast
# Out:
# 7294    Taylor Talk: The Taylor Swift Podcast | reputa...
# 7442                                 All Songs Considered
# 7443                                 KEXP Song of the Day
# 7444                                       Sound Opinions
# 7445                                             CLUBLIFE
# 7446                                     Today's Top Tune
# 7447      Live In Concert from NPR's All Songs Considered
# 7448                   A State of Trance Official Podcast
# 7449                        Above & Beyond: Group Therapy
# 7450                           Tiny Desk Concerts - Video
# 7451                                        Song Exploder
# 7452               The Joe Budden Podcast with Rory & Mal
# 7453                       In the Groove, Jazz and Beyond
# 7454                                       Toolroom Radio
# 7455                           Tiny Desk Concerts - Audio
# 7456             Techno Music - Techno Live Sets Podcasts
# 7457                                         Drink Champs
# 7458              Soundwall - Electronic Music And Beyond
# 7459           IndieFeed: Alternative / Modern Rock Music
# 7460                                      Song of the Day
# Name: Name, dtype: object

# %%
val = pd.Series.tolist(recommend["Name"])

# %%
type(val)
# Out:
# list

# %%
import random

# %%
rec = random.sample(val, 5)

# %%
rec
# Out:
# ['Techno Music - Techno Live Sets Podcasts',
#  'Taylor Talk: The Taylor Swift Podcast | reputation | 1989 | Red | Speak Now | Fearless | Taylor Swift',
#  'Sound Opinions',
#  'CLUBLIFE',
#  'A State of Trance Official Podcast']

# %%
anime_model = keras.models.load_model('/content/drive/My Drive/anime_model.h5')

# %%
df_an = pd.read_csv('/content/drive/MyDrive/anime_with_synopsis.csv')

# %%
tokenizer = Tokenizer(num_words=5000, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
MAX_SEQUENCE_LENGTH = 250

# %%
new_summary  = ['lets go out and have something cause i am hungry']
seq = tokenizer.texts_to_sequences(new_summary )
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = anime_model.predict(padded)
labels = ['Music', 'Comedy', 'Fantasy', 'Drama', 'Dementia']
print(pred, labels[np.argmax(pred)])
# Out:
# [[0.406623   0.19988005 0.11588804 0.14623362 0.13137539]] Music

# %%
pred_val = labels[np.argmax(pred)]
print(pred_val)
# Out:
# Music

# %%
recommend_an =df_an[df_an["Genders"] == pred_val].head(5)

# %%
recommend_an["Name"] #recommended animes
# Out:
# 1359         Lovedol: Lovely Idol
# 1973          CLAMP in Wonderland
# 2321    TWO-MIX: White Reflection
# 2464          Idol Densetsu Eriko
# 2870                4-Day Weekend
# Name: Name, dtype: object
